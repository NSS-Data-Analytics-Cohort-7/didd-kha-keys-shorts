# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
eco_info = pd.read_excel ('..\\data\\TEIS-NSS Project Data 10-2022.xlsx', sheet_name='ECO with Exit21-22')

# %%
eco_info.head()
# Out:
#   DISTRICT  CHILD_ID ECO_Entry_DATE  Ent SOCIAL_SCALE  Ent KNOWLEDGE_SCALE  \
# 0       ET  500335.0     2021-04-23               5.0                  3.0
# 1       ET  479453.0     2020-03-23               7.0                  7.0
# 2       ET  510663.0            NaT               NaN                  NaN
# 3       ET  452482.0     2019-01-31               2.0                  3.0
# 4       ET  506507.0            NaT               NaN                  NaN
#
#    Ent APPROPRIATE_ACTION_SCALE ECO_Exit_DATE  Exit SOCIAL_SCALE  \
# 0                           4.0    2021-10-23                6.0
# 1                           7.0    2021-08-19                7.0
# 2                           NaN           NaT                NaN
# 3                           3.0    2021-11-22                5.0
# 4                           NaN           NaT                NaN
#
#    Exit KNOWLEDGE_SCALE  Exit APPROPRIATE_ACTION_SCALE  ... OC2 Data Check  \
# ...

# %%
eco_info_check = eco_info['OC2 Data Check'].isin([1.0])

# %%
elig_df = pd.read_excel ('..\\Data\\TEIS-NSS Project Data 10-2022.xlsx', sheet_name = 'Elig Timeline Rpt 2018-2022')
# Out:
#       District  Child ID Child Status  Child Phase Init. IFSP Due Date  \
# 0           ET    453926     Inactive         IFSP          2019-03-04
# 1           ET    431729     Inactive         IFSP          2018-10-26
# 2           ET    462474     Inactive         IFSP          2019-06-28
# 3           ET    446841     Inactive  Eligibility          2018-11-23
# 4           ET    459629     Inactive         IFSP          2019-05-16
# ...        ...       ...          ...          ...                 ...
# 67605       UC    509553     Inactive         IFSP          2021-10-03
# 67606       UC    509684     Inactive         IFSP          2021-10-07
# 67607       UC    526338     Inactive         IFSP          2022-05-22
# 67608       UC    511641     Inactive  Eligibility          2021-11-22
# 67609       UC    519977     Inactive         IFSP          2022-03-07
#
#       IFSP Due Date IFSP Late Reason Active Ref. Date  \
# 0        2019-03-27           System       2019-01-18
# ...

# %%
elig_df.head()
# Out:
#   District  Child ID Child Status  Child Phase Init. IFSP Due Date  \
# 0       ET    453926     Inactive         IFSP          2019-03-04
# 1       ET    431729     Inactive         IFSP          2018-10-26
# 2       ET    462474     Inactive         IFSP          2019-06-28
# 3       ET    446841     Inactive  Eligibility          2018-11-23
# 4       ET    459629     Inactive         IFSP          2019-05-16
#
#   IFSP Due Date IFSP Late Reason Active Ref. Date Parent Consent/Intake Date  \
# 0    2019-03-27           System       2019-01-18                 2019-02-04
# 1    2018-10-26              NaN       2018-09-11                 2018-09-25
# 2    2019-06-14              NaN       2019-05-14                 2019-05-30
# 3           NaT              NaN       2018-10-09                 2018-10-25
# 4    2019-04-24              NaN       2019-04-01                 2019-04-10
#
#   Date Dev. Evaluator Rec'd. Ref.  ... # Days Parent Consent to Dev. Eval.  \
# ...

# %%
elig_df['Exit Reason'].value_counts(dropna = False)
# Out:
# Parent decline                                                          12725
# Ineligible for Part C                                                   10340
# Unable to contact                                                        8748
# NaN                                                                      8154
# 618 - Parent withdraw                                                    7111
# 618 - Part B eligibility not determined                                  6715
# 618 - Part B eligible                                                    5508
# 618 - Attempts to contact unsuccessful                                   2721
# No meeting occurred                                                      1920
# 618 - Moved out of state                                                 1052
# 618 - Not eligible for Part B – Exit with referral to other programs      938
# 618 - Not eligible for Part B – Exit with no referrals                    704
# ...

# %%
eco_info['Exit Reason'].value_counts(dropna = False)

# %%
eco_info  = eco_info[(eco_info ['OC1 Data Check'] == 1
                            )]

# %%
eco_info  = eco_info[(eco_info ['OC2 Data Check'] == 1
                            )]

# %%
eco_info  = eco_info[(eco_info ['OC3 Data Check'] == 1
                            )]

# %%
eco_info.rename(columns = {'CHILD_ID':'Child ID'}, inplace = True)
eco_info
# Out:
#      DISTRICT  Child ID ECO_Entry_DATE  Ent SOCIAL_SCALE  Ent KNOWLEDGE_SCALE  \
# 0          ET  500335.0     2021-04-23               5.0                  3.0
# 1          ET  479453.0     2020-03-23               7.0                  7.0
# 3          ET  452482.0     2019-01-31               2.0                  3.0
# 5          ET  494216.0     2021-01-06               2.0                  4.0
# 6          ET  449725.0     2020-08-06               4.0                  5.0
# ...       ...       ...            ...               ...                  ...
# 8624       UC  490337.0     2020-11-09               3.0                  1.0
# 8626       UC  483729.0     2020-08-25               1.0                  3.0
# 8627       UC  485978.0     2020-08-19               1.0                  3.0
# 8628       UC  488802.0     2020-09-21               4.0                  4.0
# 8630       UC  490688.0     2020-10-27               4.0                  5.0
#
# ...
